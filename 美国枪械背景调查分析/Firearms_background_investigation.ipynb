# %%
import pandas as pd
df = pd.read_csv('../data/firearms_background_investigation.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14190 entries, 0 to 14189
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      14190 non-null  object
#  1   state                      14190 non-null  object
#  2   permit                     14166 non-null  float64
#  3   permit_recheck             2805 non-null   float64
#  4   handgun                    14170 non-null  float64
#  5   long_gun                   14171 non-null  float64
#  6   other                      7205 non-null   float64
#  7   multiple                   14190 non-null  int64
#  8   admin                      14167 non-null  float64
#  9   prepawn_handgun            12247 non-null  float64
#  10  prepawn_long_gun           12245 non-null  float64
#  11  prepawn_other              6820 non-null   float64
#  12  redemption_handgun         12250 non-null  float64
# ...

# %%
df.shape
# Out:
# (14190, 27)

# %%
df.head(10)
# Out:
#      month                 state   permit  permit_recheck  handgun  long_gun  \
# 0  2020-04               Alabama  21276.0           386.0  28951.0   12512.0
# 1  2020-04                Alaska     85.0            68.0   3942.0    3275.0
# 2  2020-04               Arizona   4500.0           675.0  33391.0   13143.0
# 3  2020-04              Arkansas   3085.0           801.0  13814.0    8463.0
# 4  2020-04            California  24460.0             0.0  59219.0   31759.0
# 5  2020-04              Colorado   1763.0             0.0  29865.0   16199.0
# 6  2020-04           Connecticut   3796.0           172.0   4921.0    1802.0
# 7  2020-04              Delaware    359.0             0.0   3572.0    1308.0
# 8  2020-04  District of Columbia    444.0             0.0    100.0       1.0
# 9  2020-04               Florida   2258.0             0.0  84431.0   26731.0
#
#     other  multiple  admin  prepawn_handgun  ...  returned_other  \
# ...

# %%
df.columns
# Out:
# Index(['month', 'state', 'permit', 'permit_recheck', 'handgun', 'long_gun',
#        'other', 'multiple', 'admin', 'prepawn_handgun', 'prepawn_long_gun',
#        'prepawn_other', 'redemption_handgun', 'redemption_long_gun',
#        'redemption_other', 'returned_handgun', 'returned_long_gun',
#        'returned_other', 'rentals_handgun', 'rentals_long_gun',
#        'private_sale_handgun', 'private_sale_long_gun', 'private_sale_other',
#        'return_to_seller_handgun', 'return_to_seller_long_gun',
#        'return_to_seller_other', 'totals'],
#       dtype='object')
